# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

colors = [
    (127/255, 127/255, 127/255),
    (210/255, 140/255, 140/255),
    (255/255, 114/255, 114/255),
    (231/255, 70/255, 156/255),
    (186/255, 183/255, 75/255),
    (170/255, 255/255, 0/255),
    (0/255, 85/255, 255/255),
    (255/255, 0/255, 255/255),
    (255/255, 255/255, 0/255),
    (169/255, 255/255, 184/255),
    (255/255, 160/255, 165/255),
    (0/255, 50/255, 128/255),
    (111/255, 74/255, 0/255),
]

labels = [
    'Black Background',
    'Abdominal Wall',
    'Liver',
    'Gastrointestinal Tract',
    'Fat',
    'Grasper',
    'Connective Tissue',
    'Blood',
    'Cystic Duct',
    'L-hook Electrocautery',
    'Gallbladder',
    'Hepatic Vein',
    'Liver Ligament'    
]

patches = [mpatches.Patch(color=colors[i], label=labels[i]) for i in range(len(labels))]

plt.legend(handles=patches, loc='center')
plt.axis('off')
plt.show()
